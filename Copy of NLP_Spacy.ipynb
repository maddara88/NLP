# %%
# !pip show spacy
# Out:
# Name: spacy
# Version: 3.5.1
# Summary: Industrial-strength Natural Language Processing (NLP) in Python
# Home-page: https://spacy.io
# Author: Explosion
# Author-email: contact@explosion.ai
# License: MIT
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: catalogue, cymem, jinja2, langcodes, murmurhash, numpy, packaging, pathy, preshed, pydantic, requests, setuptools, smart-open, spacy-legacy, spacy-loggers, srsly, thinc, tqdm, typer, wasabi
# Required-by: en-core-web-sm, fastai

# %%
text = "While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM),  It is the science and engineering of making intelligent machines, especially intelligent computer programs. It is related to the similar task of using computers to understand human intelligence, but AI does not have to confine itself to methods that are biologically observable."

# %%
print(text)
# Out:
# While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM),  It is the science and engineering of making intelligent machines, especially intelligent computer programs. It is related to the similar task of using computers to understand human intelligence, but AI does not have to confine itself to methods that are biologically observable.

# %%
import spacy

# %%
#download the english model
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp

# %%
#Tokem

# %%
doc = nlp(text)

# %%
doc
# Out:
# While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM),  It is the science and engineering of making intelligent machines, especially intelligent computer programs. It is related to the similar task of using computers to understand human intelligence, but AI does not have to confine itself to methods that are biologically observable.

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for word in doc:
  print(word)
# Out:
# While
# a
# number
# of
# definitions
# of
# artificial
# intelligence
# (
# AI
# )
# have
# surfaced
# over
# the
# last
# few
# decades
# ,
# John
# McCarthy
# offers
# the
# following
# definition
# in
# this
# 2004
# paper
# (
# PDF
# ,
# 106
# KB
# )
# (
# link
# resides
# outside
# IBM
# )
# ,
#
# It
# is
# the
# science
# and
# engineering
# of
# making
# intelligent
# machines
# ,
# especially
# intelligent
# computer
# programs
# .
# It
# is
# related
# to
# the
# similar
# task
# of
# using
# computers
# to
# understand
# human
# intelligence
# ,
# but
# AI
# does
# not
# have
# to
# confine
# itself
# to
# methods
# that
# are
# biologically
# observable
# .

# %%
sentences =[]
for sent in doc.sents:
  sentences.append(sent)
  print(sent)
# Out:
# While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM),  It is the science and engineering of making intelligent machines, especially intelligent computer programs.
# It is related to the similar task of using computers to understand human intelligence, but AI does not have to confine itself to methods that are biologically observable.

# %%
sentences
# Out:
# [While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM),  It is the science and engineering of making intelligent machines, especially intelligent computer programs.,
#  It is related to the similar task of using computers to understand human intelligence, but AI does not have to confine itself to methods that are biologically observable.]

# %%
sentences[0]
# Out:
# While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM),  It is the science and engineering of making intelligent machines, especially intelligent computer programs.

# %%
sentences1 = sentences[1]

# %%
for p,q in enumerate(sentences1):
  print(f" {p} \t {q}")
# Out:
#  0 	 It
#  1 	 is
#  2 	 related
#  3 	 to
#  4 	 the
#  5 	 similar
#  6 	 task
#  7 	 of
#  8 	 using
#  9 	 computers
#  10 	 to
#  11 	 understand
#  12 	 human
#  13 	 intelligence
#  14 	 ,
#  15 	 but
#  16 	 AI
#  17 	 does
#  18 	 not
#  19 	 have
#  20 	 to
#  21 	 confine
#  22 	 itself
#  23 	 to
#  24 	 methods
#  25 	 that
#  26 	 are
#  27 	 biologically
#  28 	 observable
#  29 	 .

# %%
for word in sentences1:
  print(f"{word}\t\t {word.is_punct}\t\t{word.is_currency}\t\t {word.is_stop}")
# Out:
# It		 False		False		 True
# is		 False		False		 True
# related		 False		False		 False
# to		 False		False		 True
# the		 False		False		 True
# similar		 False		False		 False
# task		 False		False		 False
# of		 False		False		 True
# using		 False		False		 True
# computers		 False		False		 False
# to		 False		False		 True
# understand		 False		False		 False
# human		 False		False		 False
# intelligence		 False		False		 False
# ,		 True		False		 False
# but		 False		False		 True
# AI		 False		False		 False
# does		 False		False		 True
# not		 False		False		 True
# have		 False		False		 True
# to		 False		False		 True
# confine		 False		False		 False
# itself		 False		False		 True
# to		 False		False		 True
# methods		 False		False		 False
# that		 False		False		 True
# are		 False		False		 True
# biologically		 False		False		 False
# observable		 False		False		 False
# .		 True		False		 False

# %%
for word in sentences[0].ents:
  print(f"{word.text}\t\t {word.label_}")
# Out:
# AI		 ORG
# the last few decades		 DATE
# John McCarthy		 PERSON
# 2004		 DATE
# PDF		 ORG
# 106		 CARDINAL
# KB		 PERSON
# IBM		 ORG

# %%
spacy.displacy.render(sentences[0],style = "ent",jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">While a number of definitions of artificial intelligence (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) have surfaced over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John McCarthy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  offers the following definition in this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  paper (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PDF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     106
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) (link resides outside
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ),  It is the science and engineering of making intelligent machines, especially intelligent computer programs. </div></span>

# %%
stop_words = []
non_stop_words = []
punch_words = []

for word in sentences[0]:
  if word.is_stop:
    stop_words.append(word)
  elif word.is_punct:
    punch_words.append(word)
  else:
    non_stop_words.append(word.lower_)

# %%
stop_words
# Out:
# [While,
#  a,
#  of,
#  of,
#  have,
#  over,
#  the,
#  last,
#  few,
#  the,
#  in,
#  this,
#  It,
#  is,
#  the,
#  and,
#  of]

# %%
non_stop_words
# Out:
# ['number',
#  'definitions',
#  'artificial',
#  'intelligence',
#  'ai',
#  'surfaced',
#  'decades',
#  'john',
#  'mccarthy',
#  'offers',
#  'following',
#  'definition',
#  '2004',
#  'paper',
#  'pdf',
#  '106',
#  'kb',
#  'link',
#  'resides',
#  'outside',
#  'ibm',
#  ' ',
#  'science',
#  'engineering',
#  'making',
#  'intelligent',
#  'machines',
#  'especially',
#  'intelligent',
#  'computer',
#  'programs']

# %%
punch_words
# Out:
# [(, ), ,, (, ,, ), (, ), ,, ,, .]

# %%
from collections import Counter

# %%
c = Counter(non_stop_words)

# %%
c.most_common(5)
# Out:
# [('intelligent', 2),
#  ('number', 1),
#  ('definitions', 1),
#  ('artificial', 1),
#  ('intelligence', 1)]
